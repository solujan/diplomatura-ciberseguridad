# %%
import requests
import base64
import string

# %%
email = 'solujan@gmail.com'
url = f'https://ciberseguridad.diplomatura.unc.edu.ar/cripto/second-preimage/{email}/challenge'

# Solicitud
request = requests.get(url)
request.content
# Out:
# b'd9c026'

# %%
from hashlib import sha256
key = sha256(email.encode()).hexdigest()[:6]
key
# Out:
# 'd9c026'

# %%
def get_segunda_imagen():
  for index in string.printable[:-6]:
    for index1 in string.printable[:-6]:
      for index2 in string.printable[:-6]:
        for index3 in string.printable[:-6]:
          text = email.encode() + index.encode() + index1.encode() + index2.encode() + index3.encode()
          aux = sha256(text).hexdigest()[:6]
          if aux == key:
            print(text)
            return text

# %%
text = get_segunda_imagen()
print(sha256(text).hexdigest()[:6])
# Out:
# b'solujan@gmail.come1Kn'
# d9c026

# %%
curl -F message='solujan@gmail.come1Kn' https://ciberseguridad.diplomatura.unc.edu.ar/cripto/second-preimage/solujan@gmail.com/answer

# %%
string.printable
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'
